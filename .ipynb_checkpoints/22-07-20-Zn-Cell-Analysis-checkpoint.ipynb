# %%
import sys
sys.path.insert(0, '/Users/kedzie/Documents/Berkeley/notebooks/utilities')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from collections.abc import Iterable

from utility_functions.utils import * #read_data, read_press, getnearpos, folder_files, headspace
from matplotlib import rcParams as rc

# %%
def plot_cycle(disch, chrg, press, channel, style=None, n=None, leg='', endp=None):
    color= 'xkcd:ocean blue'
    if n==None:
        n=2
#     color='#045a8d'
#     color='xkcd:cerulean'
    #find currents for charge and discharge and //normalize by area
    disc_i= np.mean(disch['I/mA']) #/(np.pi*0.6**2)
    chrg_i= np.mean(chrg['I/mA']) #/(np.pi*0.6**2)
    print('discharge current (mA): ' +str(disc_i))
    #find the final capacity reached on discharge in mAh
    cap=disch['Capacity/mA.h'].iloc[-1]
    if style ==None:
        style = 'solid'
        
    x1=disch['Capacity/mA.h'] #/(np.pi*0.6**2)
    y1=disch['Ewe/V']
    
    x2=(cap-chrg['Capacity/mA.h']) #/(np.pi*0.6**2)
    y2=chrg['Ewe/V']
    
    #fig, (ax, ax3)= plt.subplots(2, sharex=True, figsize= (9,10)) 
    #fig, ax= plt.subplots( figsize=(8.275,5))
    fig, ax= plt.subplots( figsize=(7,5))
    ax2 = ax.twinx()
    ax.tick_params(axis='both', which='major', labelsize=18)
    ax2.tick_params(axis='y', which='major', labelsize=15)
    
    ax.plot(x1, y1, c=color, linestyle=style, label=leg, linewidth=2)
    if (str(disch) != str(chrg)):
        ax.plot(x2, y2, c=color, linestyle=style, label='', linewidth=2)
    #ax.plot([0.01,cap],[2.27,2.27], c='k', linestyle=(0,(1,5)), linewidth=2)
    
    st1=disch['time/s'].iloc[0]
    end1=disch['time/s'].iloc[-1]
    
    st2=chrg['time/s'].iloc[0]
    end2=chrg['time/s'].iloc[-1]
    
    #determine start and end indices in pressure df for discharge and charge
    st_p1 = getnearpos(press['time/s'],st1)
    end_p1 = getnearpos(press['time/s'],end1)
    
    
    st_p2 = getnearpos(press['time/s'],st2)
    end_p2 = getnearpos(press['time/s'],end2)
    
    temp = press['temperature/C']+273
    umoles = press['pressure/torr']/760*headspace(channel)/temp/0.082057
    umoles = umoles-umoles.iloc[st_p1]
    elec_oxy= x1.iloc[-1]*3.6/96485/umoles[end_p1]
    
    x=[0,cap] #/(np.pi*0.6**2)]
    y=[0,-cap*3.6/n/96485*10**6]
    
    disch_cap=(press['time/s']-press['time/s'].iloc[st_p1])*-disc_i/3600
    char_cap=cap -(press['time/s']-press['time/s'].iloc[st_p2])*chrg_i/3600 #divide cap by/(np.pi*.6**2)

    gap= umoles[end_p1-1]-umoles[st_p2]
    print((disch_cap.iloc[-1]*3.6/96485/(umoles[end_p1]*10**(-6))))
    #line1, = ax2.plot(x, y, 'k-' , label= str(n)+' e$^-$/O$_2$',linewidth= 2, linestyle = '--')
    if endp ==True:
        end_p1 = end_p1-4
        gap = umoles[end_p1-3]-umoles[st_p2]
    ax2.plot(disch_cap[st_p1:end_p1], (umoles)[st_p1:end_p1], 'o', color='#001933', label='discharge', linewidth=3, markevery=(0.0,0.02))# (0,(6,6))) # color '#9E0003' '#ec7014'
    if (str(disch) != str(chrg)):
        ax2.plot(char_cap[st_p2:end_p2+1], (umoles)[st_p2:end_p2+1]+gap, 'o', mfc='white', color='#001933', label='charge', linewidth=3, markevery=(0.0,0.02))# (0,(6,6)))
    
    
    #slope_c, int_c = np.polyfit(char_cap[st_p2:end_p2], umoles[st_p2:end_p2], 1)
    #epermol_c = 1/(slope_c/3.6*96485/10**6)
    #slope_dis, int_dis = np.polyfit(disch_cap[st_p1:end_p1], umoles[st_p1:end_p1], 1)
    #epermol_d = -1/(slope_dis/3.6*96485/10**6)
    
    ax2.legend(fontsize=14 )#,  loc='upper right')
    ax.set_ylabel('Voltage (V vs. Zn/Zn$^{2+}$)', color=color, fontsize=20)
    ax.set_xlabel('Capacity (mAh)', fontsize=20)
    ax2.set_ylabel('n$_{gas}$ ($\mu$mol)', fontsize=20)
    plt.tight_layout()
    #ax.set_ylim([0,3.5])
    print("o2 consumed: "+ str(umoles[st_p1]-(umoles[end_p1] )))
    print("o2 evolved: "+ str(umoles[end_p2]-(umoles[st_p2+1] )))
    print((umoles[end_p2]-(umoles[st_p2+1]))/(umoles[st_p1]-(umoles[end_p1])))

    epermol_c = cap * 3.6 / 96485 *10**6 / (umoles[end_p2-1]-(umoles[st_p2+1]))
    epermol_d = cap * 3.6 / 96485 *10**6 / (umoles[st_p1]-(umoles[end_p1]))
    
    print('e per mol on discharge = ' + str(epermol_d))
    #print('e per mol on charge = ' + str(epermol_c))
    if chrg['Capacity/mA.h'].iloc[-1]==0:
        print('final charge capacity: ', chrg['Capacity/mA.h'].iloc[-2] )
    else:
        print('final charge capacity: ', chrg['Capacity/mA.h'].iloc[-1] )


    return

# %%
znotf2_0_5M_c2_p = read_press('/Users/kedzie/Documents/Berkeley/Research/Data/2021/211220_Zn_0-5M_ZnOTf2_cycle_500uA_test2/211220_Zn_0-5M_ZnOTf2_cycle_500uA_test2_Ch1__2021-12-20_10.21_12.txt')
znotf2_0_5M_c2_ec = folder_files('/Users/kedzie/Documents/Berkeley/Research/Data/2021/211220_Zn_0-5M_ZnOTf2_cycle_500uA_test2/')

plot_cycle(znotf2_0_5M_c2_ec[1], znotf2_0_5M_c2_ec[3], znotf2_0_5M_c2_p, 1, n=2)

plt.figure()
plt.plot(znotf2_0_5M_c2_p['time/s'], znotf2_0_5M_c2_p['pressure/torr'])
plt.plot(znotf2_0_5M_c2_p['time/s'].iloc[30], znotf2_0_5M_c2_p['pressure/torr'].iloc[30], 'mo')
# Out:
# discharge current (mA): -0.5000162462140992
# -8.323695944778084
# o2 consumed: 15.665949298537782
# o2 evolved: 8.274583809020669
# 0.5281891094715209
# e per mol on discharge = 2.38185304373009

# %%
znotf2_4M_rpt_p = read_press('/Users/kedzie/Documents/Berkeley/Research/Data/2022/220623_Zn_4M_ZnOTf2_XC72_rpt/220623_Zn_4M_ZnOTf2_XC72_rpt_p_Ch4__2022-06-23_17.52_19.txt')
znotf2_4M_rpt_ec = folder_files('/Users/kedzie/Documents/Berkeley/Research/Data/2022/220623_Zn_4M_ZnOTf2_XC72_rpt/')

plot_cycle(znotf2_4M_rpt_ec[1], znotf2_4M_rpt_ec[3], znotf2_4M_rpt_p, 4, n=4)
plt.suptitle('4M ZnOTf$_2$ with 500$\mu$A current', fontsize=16, y=1.02)


p50_1M_rpt_p = read_press('/Users/kedzie/Documents/Berkeley/Research/Data/2022/220623_Zn_1MZnOTf2_P50_rpt/220623_Zn_1MZnOTf2_P50_rpt_p_Ch3__2022-06-23_17.37_25.txt')
p50_1M_rpt_ec = folder_files('/Users/kedzie/Documents/Berkeley/Research/Data/2022/220623_Zn_1MZnOTf2_P50_rpt/')

plot_cycle(p50_1M_rpt_ec[1], p50_1M_rpt_ec[3], p50_1M_rpt_p, 3, n=2)
plt.suptitle('1M ZnOTf$_2$ P50 electrode with 500$\mu$A current', fontsize=16, y=1.02)
plt.figure()
plt.plot( p50_1M_rpt_p['time/s'], p50_1M_rpt_p['pressure/torr'])

p50_2 = read_press('/Users/kedzie/Documents/Berkeley/Research/Data/2022/220627_Zn_1MZnOTf2_P50_cycle/220627_Zn_1MZnOTf2_P50_p_Ch3__2022-06-27_12.34_26.txt')
p50_2_ec = folder_files('/Users/kedzie/Documents/Berkeley/Research/Data/2022/220627_Zn_1MZnOTf2_P50_cycle/')

plot_cycle(p50_2_ec[1], p50_2_ec[3], p50_2, 3, n=2)

plt.figure()
plt.plot( p50_2['time/s'], p50_2['pressure/torr'], 'o')
plt.ylim(930,1180)
# Out:
# discharge current (mA): -0.5001735356498673
# -7.547568977372361
# o2 consumed: 14.826535132941459
# o2 evolved: 7.456858540137915
# 0.5029400647741586
# e per mol on discharge = 2.5174478935822946
# final charge capacity:  0.999990635448032
# discharge current (mA): -0.5001419743636364
# -7.4198340568333405
# o2 consumed: 15.070180287959644
# o2 evolved: 8.864370715604835
# 0.5882060165323334
# e per mol on discharge = 2.4765885003212014
# final charge capacity:  0.999902155664232
# discharge current (mA): -0.5000723052658228
# -9.265150412898516
# o2 consumed: 12.045696753158936
# o2 evolved: 6.317467633567475
# 0.5244584653777494
# e per mol on discharge = 3.098019367715697
# final charge capacity:  0.9999081823560928
# (930.0, 1180.0)

# %%
zinc_3_5M_p = read_press('/Users/kedzie/Documents/Berkeley/Research/Data/2022/220624_Zn_3-5M_ZnOTf2_XC72/220624_Zn_3-5M_ZnOTf2_XC72_p_Ch4__2022-06-24_16.18_30.txt')
zinc_3_5M_ec = folder_files('/Users/kedzie/Documents/Berkeley/Research/Data/2022/220624_Zn_3-5M_ZnOTf2_XC72/')

plot_cycle(zinc_3_5M_ec[1], zinc_3_5M_ec[3], zinc_3_5M_p, 4, n=4)
plt.suptitle('3.5M ZnOTf$_2$ XC72 electrode with 500$\mu$A current', fontsize=16, y=1.02)
# Out:
# discharge current (mA): -0.5001325888943489
# -241.03540653625626
# o2 consumed: 0.46301665082032173
# o2 evolved: 1.5423392549243289
# 3.331066500938536
# e per mol on discharge = 80.6062634734558
# final charge capacity:  1.000005337927077
# Text(0.5, 1.02, '3.5M ZnOTf$_2$ XC72 electrode with 500$\\mu$A current')

# %%
#argon cell
argon_zn_xc72_3_5M_p = read_press('/Users/kedzie/Documents/Berkeley/Research/Data/2022/220627_Zn_3-5M_ZnOTf2_XC72_Argon/220627_Zn_3-5M_ZnOTf2_XC72_Argon_p_Ch4__2022-06-27_11.26_44.txt')
argon_zn_xc72_3_5M_ec = folder_files('/Users/kedzie/Documents/Berkeley/Research/Data/2022/220627_Zn_3-5M_ZnOTf2_XC72_Argon/')
plot_cycle(argon_zn_xc72_3_5M_ec[1], argon_zn_xc72_3_5M_ec[3], argon_zn_xc72_3_5M_p, 4, n=4)

umoles_disch = 1.146
umoles_charge =0.9148
h2_mAh_d = umoles_disch*10**-6 * 2 *96485 /3.6
h2_mAh_c = umoles_charge*10**-6 * 2 *96485 /3.6


print(h2_mAh_c/1*100, '%')
# Out:
# discharge current (mA): -0.5000715596593673
# 96.0974295536578
# o2 consumed: -1.163603305668076
# o2 evolved: 0.9288197510353768
# -0.7982271505340048
# e per mol on discharge = -32.07077601764167
# 4.903582111111111 %

# %%
cv_zn = folder_files('/Users/kedzie/Documents/Berkeley/Research/Data/2022/220708_Zn_3_electrode_test_CV/')
initial=0
x=cv_zn[1]['Ewe/V']

fig, ax = plt.subplots()
ax3 = ax.twiny()
for i in range(1,4):
    df = cv_zn[1].loc[cv_zn[1]['cycle number'] == i]
    ax.plot(df['Ewe/V'][initial:], df['<I>/mA'][initial:], 'o', markersize=2, label= str(i))
ax.set_ylim(-0.04,0.025)
#plt.plot(cv_zn[1]['<Ece>/V'], cv_zn[1]['<I>/mA'])


ax.legend(title= 'cycle #')

ax.set_xlabel ('Voltage vs. AgCl/Ag')# Zn/Zn$^{2+}$')
ax.set_ylabel ('I (mA)')

she_axis = [-1, -0.76, 0, 0.22, 1.23, 2, 3]
newpos = [x-0.22 for x in she_axis]

ax3.set_xticks(newpos)
ax3.set_xticklabels(she_axis)
ax3.xaxis.set_ticks_position('bottom') # set the position of the second x-axis to bottom
ax3.xaxis.set_label_position('bottom') # set the position of the second x-axis to bottom
ax3.spines['bottom'].set_position(('outward', 50))
ax3.set_xlabel('Voltage vs. SHE')
ax3.set_xlim(ax.get_xlim())

# ax2 = ax.twiny()
# axis_labels = [0,1]
# zn_conversion = [x-0.98 for x in axis_labels]
# ax2.set_xticks(zn_conversion)
# ax2.set_xticklabels(axis_labels)
# ax2.xaxis.set_ticks_position('bottom') # set the position of the second x-axis to bottom
# ax2.xaxis.set_label_position('bottom') # set the position of the second x-axis to bottom
# ax2.spines['bottom'].set_position(('outward',100))
# ax2.set_xlabel('Voltage vs. Zn/Zn$^{2+}$')


#plt.savefig('/Users/kedzie/Documents/Berkeley/Research/Data/2021/211007_Zn_O2_OTfinH2O_solventstability_Ar_oxidativeLSV/211007_ZnOTf2stabilitywindow.png', transparent = True, dpi=600, bbox_inches='tight')

#ax.set_ylim([-2,2])


def plot_cv_zn(cv_file, metal='zn'):
    x=cv_file['Ewe/V']
    num_cycles = pd.unique(cv_file['cycle number'])
    fig, ax = plt.subplots()
    ax3 = ax.twiny()
    for i in num_cycles:
        df = cv_file.loc[cv_file['cycle number'] == i]
        ax.plot(df['Ewe/V'], df['<I>/mA'], 'o', markersize=2, label= str(int(i)))
    #ax.set_ylim(-0.12, -0.04)
    #ax.set_xlim(-1.2, 0)


    #plt.plot(cv_zn[1]['<Ece>/V'], cv_zn[1]['<I>/mA'])
    ax.legend(title = 'cycle #')

    ax.set_xlabel ('Voltage vs. AgCl/Ag')# Zn/Zn$^{2+}$')
    ax.set_ylabel ('I (mA)')

    she_axis = [-1, -0.76, 0, 0.22, 1.23, 2, 3]
    newpos = [x-0.22 for x in she_axis]

    ax3.set_xticks(newpos)
    ax3.set_xticklabels(she_axis)
    ax3.xaxis.set_ticks_position('bottom') # set the position of the second x-axis to bottom
    ax3.xaxis.set_label_position('bottom') # set the position of the second x-axis to bottom
    ax3.spines['bottom'].set_position(('outward', 50))
    ax3.set_xlabel('Voltage vs. SHE')
    ax3.set_xlim(ax.get_xlim())
    
    #ax2 = ax.twiny()
#     axis_labels = [0,1]
#     zn_conversion = [x-0.98 for x in axis_labels]
#     ax2.set_xticks(zn_conversion)
#     ax2.set_xticklabels(axis_labels)
#     ax2.xaxis.set_ticks_position('bottom') # set the position of the second x-axis to bottom
#     ax2.xaxis.set_label_position('bottom') # set the position of the second x-axis to bottom
#     ax2.spines['bottom'].set_position(('outward',100))
#     ax2.set_xlabel('Voltage vs. Zn/Zn$^{2+}$')




    return    

initial_zn_test = folder_files('/Users/kedzie/Documents/Berkeley/Research/Data/2022/220708_Zn_3_electrode_test_CV/')
plot_cv_zn(initial_zn_test[1])



cv_rpt_znotf= folder_files('/Users/kedzie/Documents/Berkeley/Research/Data/2022/220713_Zn_3electrodecell_CV/')
plot_cv_zn(cv_rpt_znotf[1])
#plt.savefig('/Users/kedzie/Documents/Berkeley/Research/Data/2022/220713_Zn_3electrodecell_CV/220713_Zn_3electrodecell_CV.png', transparent = True, dpi=600, bbox_inches='tight')


    
cv_naotf_zn = folder_files('/Users/kedzie/Documents/Berkeley/Research/Data/2022/220713_Zn_NaOTf_3electrode_CV_EIS/')
plot_cv_zn(cv_naotf_zn[3])
#plt.savefig('/Users/kedzie/Documents/Berkeley/Research/Data/2022/220713_Zn_NaOTf_3electrode_CV_EIS/220713_Zn_NaOTf_3electrode_CV_EIS.png', transparent = True, dpi=600, bbox_inches='tight')



cv_znotf2_argon = folder_files('/Users/kedzie/Documents/Berkeley/Research/Data/2022/220714_Zn_3electrode_CV_EIS_Argon/')
plot_cv_zn(cv_znotf2_argon[3]) #argon
#plt.savefig('/Users/kedzie/Documents/Berkeley/Research/Data/2022/220714_Zn_3electrode_CV_EIS_Argon/220714_Zn_3electrode_CV_EIS_Argon.png', transparent = True, dpi=600, bbox_inches='tight')



plot_cv_zn(cv_znotf2_argon[8]) #subsequent oxygen
#plt.savefig('/Users/kedzie/Documents/Berkeley/Research/Data/2022/220714_Zn_3electrode_CV_EIS_Argon/220714_Zn_3electrode_CV_EIS_O2.png', transparent = True, dpi=600, bbox_inches='tight')

# %%
sodium_zn_p = read_press('/Users/kedzie/Documents/Berkeley/Research/Data/2022/220712_Zn_NaOTfelectrolyte_cycle/220712_Zn_NaOTfelectrolyte_cycle_p_Ch4__2022-07-12_14.44_40.txt')
sodium_zn = folder_files('/Users/kedzie/Documents/Berkeley/Research/Data/2022/220712_Zn_NaOTfelectrolyte_cycle/')

plot_cycle(sodium_zn[1],sodium_zn[3],sodium_zn_p, 4, n=4)
#plt.savefig('/Users/kedzie/Documents/Berkeley/Research/Data/2022/220712_Zn_NaOTfelectrolyte_cycle/220712_Zn_NaOTfelectrolyte_cycle.png', transparent = True, dpi=600, bbox_inches='tight')



plt.figure()
plt.plot(sodium_zn_p['time/s'], sodium_zn_p['pressure/torr'])
plt.ylim(900,1200)


sodium_zn_100_p = read_press('/Users/kedzie/Documents/Berkeley/Research/Data/2022/220713_Zn_NaOTf_100uA_cycle/220713_Zn_NaOTf_100uA_cycle_p_Ch4__2022-07-13_14.32_17.txt')
sodium_zn_100 = folder_files('/Users/kedzie/Documents/Berkeley/Research/Data/2022/220713_Zn_NaOTf_100uA_cycle/')

plot_cycle(sodium_zn_100[1],sodium_zn_100[3],sodium_zn_100_p, 4, n=2)
# Out:
# discharge current (mA): -0.5000969521339951
# -16.589710429013422
# o2 consumed: 6.730217863160945
# o2 evolved: 0.4889786398148033
# 0.07265420670723241
# e per mol on discharge = 5.545018587912165
# discharge current (mA): -0.10001789756880737
# -11.021662534101122
# o2 consumed: 1.0546437933397783
# o2 evolved: 0.0016531440319340618
# 0.0015674904099127075
# e per mol on discharge = 1.933756248437871

# %%
sodium_zinc_DME_p = read_press('/Users/kedzie/Documents/Berkeley/Research/Data/2022/220720_Zn_NaOTfelyte_P50_cycle/220720_Zn_NaOTfelyte_P50_cycle_Ch2__2022-07-20_14.04_08.txt')
sodium_zinc_DME = folder_files('/Users/kedzie/Documents/Berkeley/Research/Data/2022/220720_Zn_NaOTfelyte_P50_cycle/')

plot_cycle(sodium_zinc_DME[1],sodium_zinc_DME[3],sodium_zinc_DME_p, 2, n=2)
# Out:
# discharge current (mA): -0.4999639848086125
# -4.585323463343053
# o2 consumed: 18.136688813067366
# o2 evolved: 1.6923773989349655
# 0.09331236899844798
# e per mol on discharge = 2.057186795535848

# %%
0.07/65.38*62.36*298/0.020
# Out:
# 994.8222698072808

# %%
zinc_argon_35M_norest = read_press('/Users/kedzie/Documents/Berkeley/Research/Data/2022/220714_Zn_P50_3-5MZnOTf2_Ar/220714_Zn_P50_3-5MZnOTf2_Ar_p_cycle1_Ch4__2022-07-14_14.43_57.txt')
zinc_argon_35M_norest_ec= folder_files('/Users/kedzie/Documents/Berkeley/Research/Data/2022/220714_Zn_P50_3-5MZnOTf2_Ar/')

plot_cycle(zinc_argon_35M_norest_ec[1],zinc_argon_35M_norest_ec[3],zinc_argon_35M_norest, 4, n=2)


plt.figure()
plt.plot(zinc_argon_35M_norest_ec[0]['time/s']/60,zinc_argon_35M_norest_ec[0]['Ewe/V'], label='ocv')
plt.plot(zinc_argon_35M_norest_ec[1]['time/s']/60,zinc_argon_35M_norest_ec[1]['Ewe/V'], label='discharge')
plt.plot(zinc_argon_35M_norest_ec[2]['time/s']/60,zinc_argon_35M_norest_ec[2]['Ewe/V'], label = 'ocv2')
plt.plot(zinc_argon_35M_norest_ec[3]['time/s']/60,zinc_argon_35M_norest_ec[3]['Ewe/V'], label = 'charge')

    


plt.legend()
plt.xlabel('Time (min)')
plt.ylabel('Voltage (V vs Zn)')

plt.figure()
# Out:
# discharge current (mA): -0.2000983361751663
# 23.988880899469226
# o2 consumed: -3.681209756945691
# o2 evolved: 1.7380863181736004
# -0.4721508506528829
# e per mol on discharge = -0.0
# final charge capacity:  0.9998414251539444
# <module 'matplotlib.pyplot' from '/Users/kedzie/miniconda3/envs/py3/lib/python3.7/site-packages/matplotlib/pyplot.py'>

# %%
ar_cy1_p = read_press('/Users/kedzie/Documents/Berkeley/Research/Data/2022/220718_Zn_P50_3-5MZnOTf2_Ar_longOCV/220714_Zn_3electrode220718_Zn_P50_3-5MZnOTf2_Ar_longOCV_cy1_p_Ch3__2022-07-18_10.35_25.txt')
ar_cy2_p = read_press('/Users/kedzie/Documents/Berkeley/Research/Data/2022/220718_Zn_P50_3-5MZnOTf2_Ar_longOCV/220714_Zn_3electrode220718_Zn_P50_3-5MZnOTf2_Ar_longOCV_cy2_p_Ch3__2022-07-19_09.00_26.txt')
ar_cy3_p = read_press('/Users/kedzie/Documents/Berkeley/Research/Data/2022/220718_Zn_P50_3-5MZnOTf2_Ar_longOCV/220718_Zn_P50_3-5MZnOTf2_Ar_longOCV_cy3_p_Ch3__2022-07-19_19.05_57.txt')
ar_cy4_p = read_press('/Users/kedzie/Documents/Berkeley/Research/Data/2022/220718_Zn_P50_3-5MZnOTf2_Ar_longOCV/220718_Zn_P50_3-5MZnOTf2_Ar_longOCV_cy4_p_Ch3__2022-07-20_11.54_14.txt')
ar_cy5_p = read_press('/Users/kedzie/Documents/Berkeley/Research/Data/2022/220718_Zn_P50_3-5MZnOTf2_Ar_longOCV/220718_Zn_P50_3-5MZnOTf2_Ar_longOCV_cy5_p_Ch3__2022-07-21_09.54_35.txt')
ar_allcycles = folder_files('/Users/kedzie/Documents/Berkeley/Research/Data/2022/220718_Zn_P50_3-5MZnOTf2_Ar_longOCV/')

plot_cycle(ar_allcycles[1],ar_allcycles[3],ar_cy1_p, 3, n=4)

plot_cycle(ar_allcycles[6],ar_allcycles[8],ar_cy2_p, 3, n=4)
plot_cycle(ar_allcycles[11],ar_allcycles[13],ar_cy3_p, 3, n=4)
plot_cycle(ar_allcycles[16],ar_allcycles[18],ar_cy4_p, 3, n=4)
plot_cycle(ar_allcycles[21],ar_allcycles[23],ar_cy5_p, 3, n=4)


gasevolved_sum=0
gasevolved_sum = 1.171776691306036 + 0.5251082925626207 + 0.6310155538266855 + 0.8672241403977523 +0.7597903294394257+ 0.6660324963622628 + 1.1601084003827253 + 0.60145411969809 + 1.0611895302152874+0.75382
print(gasevolved_sum)
print(gasevolved_sum*2*96485/3.6/10**6)

fig, ax = plt.subplots()
ax2= ax.twinx()
ax.plot(ar_cy1_p['time/s'],ar_cy1_p['pressure/torr'], label='cycle1' )
ax.plot(ar_cy2_p['time/s'],ar_cy2_p['pressure/torr'] , label='cycle2')
ax.plot(ar_cy3_p['time/s'],ar_cy3_p['pressure/torr'], label='cycle3' )
ax.plot(ar_cy4_p['time/s'],ar_cy4_p['pressure/torr'], label='cycle4')

ax2.plot(ar_allcycles[0]['time/s'],ar_allcycles[0]['Ewe/V'] , '--', label='voltage1 ')
ax2.plot(ar_allcycles[5]['time/s'],ar_allcycles[5]['Ewe/V'] , '--', label='voltage2 ')
ax2.plot(ar_allcycles[10]['time/s'],ar_allcycles[10]['Ewe/V'] , '--', label='voltage3 ')


ax.legend()
ax2.legend()
# Out:
# discharge current (mA): -0.20009490537894736
# 66.20740185075861
# o2 consumed: -1.171776691306036
# o2 evolved: 0.5251082925626207
# -0.44813000331773695
# e per mol on discharge = -31.85732868494589
# final charge capacity:  0.6809622711605496
# discharge current (mA): -0.20007063719088936
# 114.60779147910702
# o2 consumed: -0.6310155538266855
# o2 evolved: 0.8672241403977523
# -1.3743308467416062
# e per mol on discharge = -59.14958884880385
# final charge capacity:  0.8076442612542046
# discharge current (mA): -0.2000717589364035
# 109.5293195776383
# o2 consumed: -0.7597903294394257
# o2 evolved: 0.6660324963622628
# -0.8766003863903644
# e per mol on discharge = -49.125284338785974
# final charge capacity:  0.8319045437706841
# discharge current (mA): -0.20007425826985853
# 71.29720269028876
# o2 consumed: -1.1601084003827253
# o2 evolved: 0.60145411969809
# -0.518446482673229
# e per mol on discharge = -32.17418187997032
# final charge capacity:  0.8169034454557631
# ...

# %%
o2_p50_35M_folder= folder_files('/Users/kedzie/Documents/Berkeley/Research/Data/2022/220714_Zn_P50_3-5MZnOTf2_Ar/')
o2_p50_35M_p =read_press('/Users/kedzie/Documents/Berkeley/Research/Data/2022/220714_Zn_P50_3-5MZnOTf2_Ar/220714_Zn_P50_3-5MZnOTf2_Ar_p_cycle1_Ch4__2022-07-14_14.43_57.txt')
plot_cycle(o2_p50_35M_folder[1],o2_p50_35M_folder[3],o2_p50_35M_p, 4, n=4)





o2_cy1_p =read_press('/Users/kedzie/Documents/Berkeley/Research/Data/2022/220718_Zn_P50_3-5MZnOTf2_O2_longOCV/220718_Zn_P50_3-5MZnOTf2_O2_longOCV_cy1_p_Ch4__2022-07-18_10.55_01.txt')
o2_cy2_p =read_press('/Users/kedzie/Documents/Berkeley/Research/Data/2022/220718_Zn_P50_3-5MZnOTf2_O2_longOCV/220718_Zn_P50_3-5MZnOTf2_O2_longOCV_cy2_p_Ch4__2022-07-19_09.00_34.txt')
o2_cy3_p = read_press('/Users/kedzie/Documents/Berkeley/Research/Data/2022/220718_Zn_P50_3-5MZnOTf2_O2_longOCV/220718_Zn_P50_3-5MZnOTf2_O2_longOCV_cy3_p_Ch4__2022-07-19_19.06_05.txt')
o2_cy4_p = read_press('/Users/kedzie/Documents/Berkeley/Research/Data/2022/220718_Zn_P50_3-5MZnOTf2_O2_longOCV/220718_Zn_P50_3-5MZnOTf2_O2_longOCV_cy4_p_Ch4__2022-07-20_11.54_02.txt')
o2_cy5_p = read_press('/Users/kedzie/Documents/Berkeley/Research/Data/2022/220718_Zn_P50_3-5MZnOTf2_O2_longOCV/220718_Zn_P50_3-5MZnOTf2_O2_longOCV_cy5_p_Ch4__2022-07-21_09.54_27.txt')
o2_ec_all = folder_files('/Users/kedzie/Documents/Berkeley/Research/Data/2022/220718_Zn_P50_3-5MZnOTf2_O2_longOCV/')

plot_cycle(o2_ec_all[1],o2_ec_all[3],o2_cy1_p, 4, n=4)
plot_cycle(o2_ec_all[6],o2_ec_all[8],o2_cy2_p, 4, n=4)
plot_cycle(o2_ec_all[11],o2_ec_all[13],o2_cy3_p, 4, n=4)
plot_cycle(o2_ec_all[16],o2_ec_all[18],o2_cy4_p, 4, n=4)
plot_cycle(o2_ec_all[21],o2_ec_all[23],o2_cy5_p, 4, n=4)



#gas_evolved_sum =
# Out:
# discharge current (mA): -0.2000983361751663
# 23.988880899469226
# o2 consumed: -3.681209756945691
# o2 evolved: 1.7380863181736004
# -0.4721508506528829
# e per mol on discharge = -0.0
# final charge capacity:  0.9998414251539444
# discharge current (mA): -0.2000934897130712
# -24.122779417716714
# o2 consumed: 2.8489439189357313
# o2 evolved: -0.46310393894546564
# -0.16255284488662927
# e per mol on discharge = 13.102797940254437
# final charge capacity:  0.4417745272318522
# discharge current (mA): -0.2000615035052632
# -126.68015848608916
# o2 consumed: 0.56591609047112
# o2 evolved: 0.48962299705529233
# 0.8651865626363188
# e per mol on discharge = 65.95240072308044
# final charge capacity:  0.7233992550108168
# discharge current (mA): -0.20006367275053305
# -178.47901959225229
# o2 consumed: 0.44295614740009626
# o2 evolved: -0.16305893659398407
# -0.36811530340203746
# e per mol on discharge = 84.26004521015182
# final charge capacity:  0.7224212090174357
# ...

# %%
plt.figure()
plt.plot(o2_cy4_p['time/s'],o2_cy4_p['pressure/torr'] )

# %%
cycle1_1M_p50 = read_press('/Users/kedzie/Documents/Berkeley/Research/Data/2022/220727_Zn_P50_1MZnOTf2_Ar_1cycle/220727_Zn_P50_1MZnOTf2_Ar_1cycle_p_Ch4__2022-07-27_13.23_57.txt')
cycle1_1M_p50_folder = folder_files('/Users/kedzie/Documents/Berkeley/Research/Data/2022/220727_Zn_P50_1MZnOTf2_Ar_1cycle/')

plot_cycle(cycle1_1M_p50_folder[1],cycle1_1M_p50_folder[3], cycle1_1M_p50, 4)
#plt.savefig('/Users/kedzie/Documents/Berkeley/Research/Data/2022/220727_Zn_P50_1MZnOTf2_Ar_1cycle/220727_Zn_1MZnOTf2_P50_1cycle_Ar.png', transparent = True, dpi=600, bbox_inches='tight')


print(cycle1_1M_p50_folder[3]['Capacity/mA.h'].iloc[-2])

cycle1_35M_p50 = read_press('/Users/kedzie/Documents/Berkeley/Research/Data/2022/220816_Zn_3-5MZnOTf2_P50_1cycle_Ar/220816_Zn_3-5MZnOTf2_P50_1cycle_Ar_Ch4__2022-08-16_13.35_45.txt')
cycle1_35M_p50_folder = folder_files('/Users/kedzie/Documents/Berkeley/Research/Data/2022/220816_Zn_3-5MZnOTf2_P50_1cycle_Ar/')
plot_cycle(cycle1_35M_p50_folder[1],cycle1_35M_p50_folder[3], cycle1_35M_p50, 4)
#plt.savefig('/Users/kedzie/Documents/Berkeley/Research/Data/2022/220816_Zn_3-5MZnOTf2_P50_1cycle_Ar/220816_Zn_3-5MZnOTf2_P50_1cycle_Ar.png', transparent = True, dpi=600, bbox_inches='tight')


calculate_umoles_total(cycle1_1M_p50, 4)
# Out:
# discharge current (mA): -0.20005392253918497
# 15.882673488876923
# o2 consumed: -4.751721370655616
# o2 evolved: 1.7593120063788774
# -0.37024729969302417
# e per mol on discharge = -7.854386633627294
# final charge capacity:  0.6260081132253011
# 0.6260081132253011
# discharge current (mA): -0.2001871356544503
# 31.86716613558572
# o2 consumed: -2.4534449382996257
# o2 evolved: 0.6079061602091969
# -0.24777656539971496
# e per mol on discharge = -15.222186760296234
# final charge capacity:  0.6945219967100356
# total gas evolved/consumed =  7.079519394977623 umoles

# %%
def calculate_umoles_total(pressure_file, channel):
    temp = pressure_file['temperature/C']+273
    umoles = pressure_file['pressure/torr']/760*headspace(channel)/temp/0.082057
    umoles = umoles-umoles.iloc[0]
    print('total gas evolved/consumed = ', umoles.iloc[-1], 'umoles')
    fig, ax = plt.subplots()
    ax.plot(pressure_file['time/s']/3600, umoles)
    ax.set_xlabel('Time (h)')
    ax.set_ylabel('$\Delta$ Gas ($\mu$mol)')
    
fig, ax = plt.subplots()
calculate_umoles_total(cycle1_35M_p50, 4)
ax2=ax.twinx()
ax.plot(cycle1_35M_p50['time/s']/60/60 ,cycle1_35M_p50['pressure/torr'])
#ax2.plot(cycle1_35M_p50_folder[0]['time/s']/60/60, cycle1_35M_p50_folder[0]['Ewe/V'])
ax2.plot(cycle1_35M_p50_folder[2]['time/s']/60/60, cycle1_35M_p50_folder[2]['Ewe/V'])
# Out:
# total gas evolved/consumed =  3.3700201066685054 umoles

# %%
celgardcell_1M_folder= folder_files('/Users/kedzie/Documents/Berkeley/Research/Data/2022/220830_Zn_1M_1cycle_Ar_Celgard_norinse/')
celgardcell_1cycle_p =read_press('/Users/kedzie/Documents/Berkeley/Research/Data/2022/220830_Zn_1M_1cycle_Ar_Celgard_norinse/220830_Zn_1M_1cycle_Ar_Celgard_norinse_Ch4__2022-08-30_10.46_42.txt')
#plot_cycle(celgardcell_1M_folder[1],celgardcell_1M_folder[3],celgardcell_1cycle_p, 4, n=2)

celgard_perforated_fold = folder_files('/Users/kedzie/Documents/Berkeley/Research/Data/2022/220830_Zn_1M_1cycle_Ar_Celgardperforated_norinse/')
celgard_press = read_press('/Users/kedzie/Documents/Berkeley/Research/Data/2022/220830_Zn_1M_1cycle_Ar_Celgardperforated_norinse/220830_Zn_1M_1cycle_Ar_Celgardperforated_norinse_p_Ch3__2022-08-30_12.30_37.txt')
plot_cycle(celgard_perforated_fold[1],celgard_perforated_fold[3],celgard_press, 4, n=2)

celgard_perforated_fold[3]['Capacity/mA.h'].iloc[-2]


calculate_umoles_total(celgardcell_1cycle_p, 4)
# Out:
# discharge current (mA): -0.20007857388481676
# 21.336306534140427
# o2 consumed: -6.362074274973594
# o2 evolved: 1.386168484318162
# -0.21787995933510465
# e per mol on discharge = -5.867091290238134
# final charge capacity:  0.5277558830049303
# total gas evolved/consumed =  5.30326724473295 umoles

# %%
p50_1cycle1M_fold = folder_files('/Users/kedzie/Documents/Berkeley/Research/Data/2022/220829_Zn_1MZnOTf2_P50_1cycle_Ar_norinse/')
p50_1cycle1M_press = read_press('/Users/kedzie/Documents/Berkeley/Research/Data/2022/220829_Zn_1MZnOTf2_P50_1cycle_Ar_norinse/220829_Zn_1MZnOTf2_P50_1cycle_Ar_norinse_p_Ch4__2022-08-29_17.32_35.txt')
plot_cycle(p50_1cycle1M_fold[1],p50_1cycle1M_fold[3],p50_1cycle1M_press, 4, n=2)

#print(p50_1cycle1M_fold[3]['Capacity/mA.h'].iloc[-2])

#calculate_umoles_total(p50_1cycle1M_press, 4)


dischargeonly_celgard = folder_files('/Users/kedzie/Documents/Berkeley/Research/Data/2022/220908_Zn_3-5M_P50_dischargeonly_Ar_norinse_celgard/')
discharge_pressure = read_press('/Users/kedzie/Documents/Berkeley/Research/Data/2022/220908_Zn_3-5M_P50_dischargeonly_Ar_norinse_celgard/220908_Zn_3-5M_P50_dischargeonly_Ar_norinse_celgard_Ch4__2022-09-08_20.46_55.txt')

calculate_umoles_total(discharge_pressure, 4)

for i in range(len(dischargeonly_celgard)):
    plt.plot(dischargeonly_celgard[i]['time/s']/3600, dischargeonly_celgard[i]['Ewe/V'])

timedelay= (dischargeonly_celgard[2]['time/s'].iloc[-1]-dischargeonly_celgard[2]['time/s'].iloc[0])/3600
print(timedelay)
# Out:
# discharge current (mA): -0.20003052269392033
# 17.743467179140968
# o2 consumed: -6.2582487352533605
# o2 evolved: 1.6307492436248907
# -0.2605759714277114
# e per mol on discharge = -5.962866628095227
# final charge capacity:  0.5953458944956461
# total gas evolved/consumed =  2.145429363553262 umoles
# 3.414111338265003

# %%
celgardcellrpt = folder_files('/Users/kedzie/Documents/Berkeley/Research/Data/2022/220923_Zn_3-5M_P50_dischargeonly_rpt/')
celgardrpt_p = read_press('/Users/kedzie/Documents/Berkeley/Research/Data/2022/220923_Zn_3-5M_P50_dischargeonly_rpt/220923_Zn_3-5M_P50_dischargeonly_rpt_p_Ch4__2022-09-23_09.57_23.txt')
plot_cycle(celgardcellrpt[1],celgardcellrpt[1],celgardrpt_p, 4, n=2)

calculate_umoles_total(celgardrpt_p, 4)
ax2=ax.twinx()
ax2.plot(celgardcellrpt[0]['time/s']/3600, celgardcellrpt[0]['Ewe/V'])
ax2.plot(celgardcellrpt[1]['time/s']/3600, celgardcellrpt[1]['Ewe/V'])
plt.plot(celgardcellrpt[2]['time/s']/3600, celgardcellrpt[2]['Ewe/V'])
# Out:
# discharge current (mA): -0.20003511940188878
# 33.48309019700828
# o2 consumed: -1.1861356505480387
# o2 evolved: 1.1344696390468414
# -0.9564417345711465
# e per mol on discharge = -31.462174859340013
# final charge capacity:  1.000185145272149
# total gas evolved/consumed =  1.2190144492364823 umoles

# %% [markdown]
# <head> copper substrate cell cycling </head>

# %%
#This is the first Cu cell I tried. I used Celgard wetted with acetone then water in between Zn and QMA:
copper_folder1 = folder_files('/Users/kedzie/Documents/Berkeley/Research/Data/2022/220903_Zn_1M_Cu_1cycle_Ar/')
copper_press1 = read_press('/Users/kedzie/Documents/Berkeley/Research/Data/2022/220903_Zn_1M_Cu_1cycle_Ar/220903_Zn_1M_Cu_1cycle_Ar_p_Ch4__2022-09-03_12.12_33.txt')
plot_cycle(copper_folder1[1],copper_folder1[3],copper_press1, 4, n=2)

#second cell without celgard - 1.5 V cutoff
copper_folder2 = folder_files('/Users/kedzie/Documents/Berkeley/Research/Data/2022/220903_Zn_1M_Cu_noCelgard_1cycle_Ar/')
copper_press2 = read_press('/Users/kedzie/Documents/Berkeley/Research/Data/2022/220903_Zn_1M_Cu_noCelgard_1cycle_Ar/220903_Zn_1M_Cu_noCelgard_1cycle_Ar_p_Ch3__2022-09-03_13.11_51.txt')
plot_cycle(copper_folder2[1],copper_folder2[3][:-180],copper_press2, 4, n=2)

calculate_umoles_total(copper_press2, 4)
plt.plot(copper_folder2[0]['time/s']/3600, copper_folder2[0]['Ewe/V'])
plt.plot(copper_folder2[1]['time/s']/3600, copper_folder2[1]['Ewe/V'])
plt.plot(copper_folder2[2]['time/s']/3600, copper_folder2[2]['Ewe/V'])
plt.plot(copper_folder2[3]['time/s']/3600, copper_folder2[3]['Ewe/V'])
plt.plot(copper_folder2[4]['time/s']/3600, copper_folder2[4]['Ewe/V'])


#repeat of cell without celgard - 0.6V cutoff

copper_folder3 = folder_files('/Users/kedzie/Documents/Berkeley/Research/Data/2022/220905_Zn_1M_Cu_noCelgard_1cycle_Ar/')
copper_press3 = read_press('/Users/kedzie/Documents/Berkeley/Research/Data/2022/220905_Zn_1M_Cu_noCelgard_1cycle_Ar/220905_Zn_1M_Cu_noCelgard_1cycle_Ar_p_Ch4__2022-09-05_09.57_47.txt')
plot_cycle(copper_folder3[1],copper_folder3[3][:-1],copper_press3, 4, n=2)

calculate_umoles_total(copper_press3, 4)
plt.plot(copper_folder3[0]['time/s']/3600, copper_folder3[0]['Ewe/V'])
plt.plot(copper_folder3[1]['time/s']/3600, copper_folder3[1]['Ewe/V'])
plt.plot(copper_folder3[2]['time/s']/3600, copper_folder3[2]['Ewe/V'])
plt.plot(copper_folder3[3]['time/s']/3600, copper_folder3[3]['Ewe/V'])
plt.plot(copper_folder3[4]['time/s']/3600, copper_folder3[4]['Ewe/V'])





copper_control = read_press('/Users/kedzie/Documents/Berkeley/Research/Data/2022/220927_Cu_1MZnOtf2_control_pressurerise/220927_Cu_1MZnOtf2_control_pressurerise_Ch4__2022-09-27_16.23_50.txt')
calculate_umoles_total(copper_control, 4)
# Out:
# discharge current (mA): -0.20015375441762856
# 67.93823573869311
# o2 consumed: -2.243787044583712
# o2 evolved: 0.5119248145617519
# -0.2281521393919666
# e per mol on discharge = -16.641800568955325
# final charge capacity:  0.4858189158969455
# discharge current (mA): -0.2001588782791186
# 63.99694986756338
# o2 consumed: -3.0326106585260817
# o2 evolved: 1.616468058735677
# -0.5330285489141285
# e per mol on discharge = -12.313337467459041
# final charge capacity:  0.841553807258606
# total gas evolved/consumed =  14.098528061929642 umoles
# discharge current (mA): -0.20023741337880377
# 59.788761924924685
# o2 consumed: -2.7078645893456184
# o2 evolved: 1.7415201499625255
# -0.6431341348510269
# e per mol on discharge = -13.79559553064632
# final charge capacity:  0.7360687520768907
# total gas evolved/consumed =  7.135263430772412 umoles
# total gas evolved/consumed =  -0.18239544310060296 umoles
